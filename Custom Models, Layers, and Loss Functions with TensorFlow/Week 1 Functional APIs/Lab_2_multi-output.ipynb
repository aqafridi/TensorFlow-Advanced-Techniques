# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Get the data from UCI dataset
URL = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URL)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 932us/sample - loss: 233.3167 - y1_output_loss: 108.1973 - y2_output_loss: 122.9854 - y1_output_root_mean_squared_error: 10.4496 - y2_output_root_mean_squared_error: 11.1411 - val_loss: 40.0765 - val_y1_output_loss: 15.4116 - val_y2_output_loss: 23.7099 - val_y1_output_root_mean_squared_error: 3.9786 - val_y2_output_root_mean_squared_error: 4.9242
# Epoch 2/500
# 614/614 [==============================] - 0s 151us/sample - loss: 44.7255 - y1_output_loss: 15.2296 - y2_output_loss: 29.6470 - y1_output_root_mean_squared_error: 3.9172 - y2_output_root_mean_squared_error: 5.4204 - val_loss: 31.1353 - val_y1_output_loss: 9.5121 - val_y2_output_loss: 21.1121 - val_y1_output_root_mean_squared_error: 3.1239 - val_y2_output_root_mean_squared_error: 4.6235
# Epoch 3/500
# 614/614 [==============================] - 0s 127us/sample - loss: 23.6521 - y1_output_loss: 9.8069 - y2_output_loss: 13.7626 - y1_output_root_mean_squared_error: 3.1278 - y2_output_root_mean_squared_error: 3.7241 - val_loss: 21.3629 - val_y1_output_loss: 8.4845 - val_y2_output_loss: 12.4478 - val_y1_output_root_mean_squared_error: 2.9486 - val_y2_output_root_mean_squared_error: 3.5593
# Epoch 4/500
# 614/614 [==============================] - 0s 135us/sample - loss: 25.4558 - y1_output_loss: 9.8514 - y2_output_loss: 15.6123 - y1_output_root_mean_squared_error: 3.1437 - y2_output_root_mean_squared_error: 3.9463 - val_loss: 21.0535 - val_y1_output_loss: 8.2629 - val_y2_output_loss: 12.3009 - val_y1_output_root_mean_squared_error: 2.9173 - val_y2_output_root_mean_squared_error: 3.5416
# Epoch 5/500
# 614/614 [==============================] - 0s 133us/sample - loss: 24.9762 - y1_output_loss: 9.9779 - y2_output_loss: 15.3309 - y1_output_root_mean_squared_error: 3.1216 - y2_output_root_mean_squared_error: 3.9028 - val_loss: 50.4728 - val_y1_output_loss: 14.4433 - val_y2_output_loss: 35.2837 - val_y1_output_root_mean_squared_error: 3.8377 - val_y2_output_root_mean_squared_error: 5.9787
# Epoch 6/500
# 614/614 [==============================] - 0s 130us/sample - loss: 25.7657 - y1_output_loss: 9.5647 - y2_output_loss: 16.2292 - y1_output_root_mean_squared_error: 3.0891 - y2_output_root_mean_squared_error: 4.0278 - val_loss: 39.0559 - val_y1_output_loss: 10.0359 - val_y2_output_loss: 29.3625 - val_y1_output_root_mean_squared_error: 3.1736 - val_y2_output_root_mean_squared_error: 5.3837
# Epoch 7/500
# 614/614 [==============================] - 0s 136us/sample - loss: 18.4226 - y1_output_loss: 7.8884 - y2_output_loss: 10.6730 - y1_output_root_mean_squared_error: 2.8072 - y2_output_root_mean_squared_error: 3.2468 - val_loss: 36.9547 - val_y1_output_loss: 11.1818 - val_y2_output_loss: 25.5316 - val_y1_output_root_mean_squared_error: 3.3618 - val_y2_output_root_mean_squared_error: 5.0649
# Epoch 8/500
# 614/614 [==============================] - 0s 131us/sample - loss: 19.8152 - y1_output_loss: 8.1789 - y2_output_loss: 11.4554 - y1_output_root_mean_squared_error: 2.8728 - y2_output_root_mean_squared_error: 3.4003 - val_loss: 16.8702 - val_y1_output_loss: 6.9029 - val_y2_output_loss: 9.5631 - val_y1_output_root_mean_squared_error: 2.6668 - val_y2_output_root_mean_squared_error: 3.1238
# Epoch 9/500
# 614/614 [==============================] - 0s 132us/sample - loss: 21.0996 - y1_output_loss: 8.2183 - y2_output_loss: 12.9574 - y1_output_root_mean_squared_error: 2.8726 - y2_output_root_mean_squared_error: 3.5844 - val_loss: 17.1185 - val_y1_output_loss: 6.4954 - val_y2_output_loss: 10.2303 - val_y1_output_root_mean_squared_error: 2.5855 - val_y2_output_root_mean_squared_error: 3.2301
# Epoch 10/500
# 614/614 [==============================] - 0s 133us/sample - loss: 19.0738 - y1_output_loss: 7.7109 - y2_output_loss: 11.3869 - y1_output_root_mean_squared_error: 2.7653 - y2_output_root_mean_squared_error: 3.3804 - val_loss: 18.1322 - val_y1_output_loss: 7.3180 - val_y2_output_loss: 10.3133 - val_y1_output_root_mean_squared_error: 2.7464 - val_y2_output_root_mean_squared_error: 3.2541
# Epoch 11/500
# 614/614 [==============================] - 0s 129us/sample - loss: 21.1603 - y1_output_loss: 8.0948 - y2_output_loss: 12.9827 - y1_output_root_mean_squared_error: 2.8520 - y2_output_root_mean_squared_error: 3.6092 - val_loss: 17.4491 - val_y1_output_loss: 6.5269 - val_y2_output_loss: 10.5011 - val_y1_output_root_mean_squared_error: 2.5896 - val_y2_output_root_mean_squared_error: 3.2777
# Epoch 12/500
# 614/614 [==============================] - 0s 138us/sample - loss: 18.7105 - y1_output_loss: 7.0272 - y2_output_loss: 11.5462 - y1_output_root_mean_squared_error: 2.6602 - y2_output_root_mean_squared_error: 3.4109 - val_loss: 30.7299 - val_y1_output_loss: 8.5686 - val_y2_output_loss: 21.6294 - val_y1_output_root_mean_squared_error: 2.9614 - val_y2_output_root_mean_squared_error: 4.6861
# Epoch 13/500
# 614/614 [==============================] - 0s 137us/sample - loss: 19.2683 - y1_output_loss: 7.4341 - y2_output_loss: 11.7282 - y1_output_root_mean_squared_error: 2.7374 - y2_output_root_mean_squared_error: 3.4315 - val_loss: 14.2647 - val_y1_output_loss: 5.9260 - val_y2_output_loss: 7.9740 - val_y1_output_root_mean_squared_error: 2.4694 - val_y2_output_root_mean_squared_error: 2.8578
# Epoch 14/500
# 614/614 [==============================] - 0s 130us/sample - loss: 16.2128 - y1_output_loss: 6.4058 - y2_output_loss: 9.6883 - y1_output_root_mean_squared_error: 2.5415 - y2_output_root_mean_squared_error: 3.1231 - val_loss: 13.9151 - val_y1_output_loss: 5.6899 - val_y2_output_loss: 7.8302 - val_y1_output_root_mean_squared_error: 2.4219 - val_y2_output_root_mean_squared_error: 2.8372
# Epoch 15/500
# 614/614 [==============================] - 0s 130us/sample - loss: 18.2743 - y1_output_loss: 6.7902 - y2_output_loss: 11.3705 - y1_output_root_mean_squared_error: 2.6103 - y2_output_root_mean_squared_error: 3.3853 - val_loss: 18.5961 - val_y1_output_loss: 7.5397 - val_y2_output_loss: 10.5817 - val_y1_output_root_mean_squared_error: 2.7820 - val_y2_output_root_mean_squared_error: 3.2949
# Epoch 16/500
# 614/614 [==============================] - 0s 138us/sample - loss: 17.2239 - y1_output_loss: 6.6736 - y2_output_loss: 10.6108 - y1_output_root_mean_squared_error: 2.5843 - y2_output_root_mean_squared_error: 3.2473 - val_loss: 12.7964 - val_y1_output_loss: 5.2354 - val_y2_output_loss: 7.2180 - val_y1_output_root_mean_squared_error: 2.3242 - val_y2_output_root_mean_squared_error: 2.7193
# Epoch 17/500
# 614/614 [==============================] - 0s 136us/sample - loss: 15.3076 - y1_output_loss: 5.6833 - y2_output_loss: 9.5885 - y1_output_root_mean_squared_error: 2.3898 - y2_output_root_mean_squared_error: 3.0978 - val_loss: 28.7498 - val_y1_output_loss: 7.8130 - val_y2_output_loss: 20.3217 - val_y1_output_root_mean_squared_error: 2.8339 - val_y2_output_root_mean_squared_error: 4.5518
# Epoch 18/500
# 614/614 [==============================] - 0s 131us/sample - loss: 16.5395 - y1_output_loss: 5.9116 - y2_output_loss: 10.5745 - y1_output_root_mean_squared_error: 2.4391 - y2_output_root_mean_squared_error: 3.2543 - val_loss: 16.1092 - val_y1_output_loss: 5.7906 - val_y2_output_loss: 10.3199 - val_y1_output_root_mean_squared_error: 2.4151 - val_y2_output_root_mean_squared_error: 3.2057
# Epoch 19/500
# 614/614 [==============================] - 0s 128us/sample - loss: 12.3806 - y1_output_loss: 5.0076 - y2_output_loss: 7.2677 - y1_output_root_mean_squared_error: 2.2481 - y2_output_root_mean_squared_error: 2.7068 - val_loss: 11.2064 - val_y1_output_loss: 4.5854 - val_y2_output_loss: 6.2720 - val_y1_output_root_mean_squared_error: 2.1783 - val_y2_output_root_mean_squared_error: 2.5419
# Epoch 20/500
# 614/614 [==============================] - 0s 124us/sample - loss: 12.8180 - y1_output_loss: 5.1558 - y2_output_loss: 7.7924 - y1_output_root_mean_squared_error: 2.2685 - y2_output_root_mean_squared_error: 2.7698 - val_loss: 27.6040 - val_y1_output_loss: 7.1972 - val_y2_output_loss: 20.1025 - val_y1_output_root_mean_squared_error: 2.7062 - val_y2_output_root_mean_squared_error: 4.5034
# Epoch 21/500
# 614/614 [==============================] - 0s 135us/sample - loss: 12.3717 - y1_output_loss: 4.8505 - y2_output_loss: 7.5292 - y1_output_root_mean_squared_error: 2.2029 - y2_output_root_mean_squared_error: 2.7421 - val_loss: 23.5504 - val_y1_output_loss: 7.3920 - val_y2_output_loss: 15.7957 - val_y1_output_root_mean_squared_error: 2.7499 - val_y2_output_root_mean_squared_error: 3.9985
# Epoch 22/500
# 614/614 [==============================] - 0s 133us/sample - loss: 12.4159 - y1_output_loss: 4.6897 - y2_output_loss: 7.6822 - y1_output_root_mean_squared_error: 2.1723 - y2_output_root_mean_squared_error: 2.7744 - val_loss: 11.2997 - val_y1_output_loss: 4.3456 - val_y2_output_loss: 6.7010 - val_y1_output_root_mean_squared_error: 2.1067 - val_y2_output_root_mean_squared_error: 2.6194
# Epoch 23/500
# 614/614 [==============================] - 0s 130us/sample - loss: 12.7748 - y1_output_loss: 4.6070 - y2_output_loss: 8.0993 - y1_output_root_mean_squared_error: 2.1557 - y2_output_root_mean_squared_error: 2.8509 - val_loss: 13.1606 - val_y1_output_loss: 3.9022 - val_y2_output_loss: 8.8671 - val_y1_output_root_mean_squared_error: 2.0063 - val_y2_output_root_mean_squared_error: 3.0225
# Epoch 24/500
# 614/614 [==============================] - 0s 132us/sample - loss: 10.7297 - y1_output_loss: 4.3330 - y2_output_loss: 6.5352 - y1_output_root_mean_squared_error: 2.0733 - y2_output_root_mean_squared_error: 2.5360 - val_loss: 10.5353 - val_y1_output_loss: 3.9884 - val_y2_output_loss: 6.2369 - val_y1_output_root_mean_squared_error: 2.0251 - val_y2_output_root_mean_squared_error: 2.5366
# Epoch 25/500
# 614/614 [==============================] - 0s 124us/sample - loss: 11.2272 - y1_output_loss: 4.3270 - y2_output_loss: 6.9599 - y1_output_root_mean_squared_error: 2.0820 - y2_output_root_mean_squared_error: 2.6254 - val_loss: 10.6015 - val_y1_output_loss: 4.1977 - val_y2_output_loss: 6.4005 - val_y1_output_root_mean_squared_error: 2.0574 - val_y2_output_root_mean_squared_error: 2.5236
# Epoch 26/500
# 614/614 [==============================] - 0s 140us/sample - loss: 11.5543 - y1_output_loss: 4.1273 - y2_output_loss: 7.4200 - y1_output_root_mean_squared_error: 2.0278 - y2_output_root_mean_squared_error: 2.7281 - val_loss: 11.0607 - val_y1_output_loss: 3.9807 - val_y2_output_loss: 6.9489 - val_y1_output_root_mean_squared_error: 1.9924 - val_y2_output_root_mean_squared_error: 2.6629
# Epoch 27/500
# 614/614 [==============================] - 0s 138us/sample - loss: 12.1770 - y1_output_loss: 4.1183 - y2_output_loss: 7.9773 - y1_output_root_mean_squared_error: 2.0387 - y2_output_root_mean_squared_error: 2.8321 - val_loss: 12.6599 - val_y1_output_loss: 3.6860 - val_y2_output_loss: 8.6446 - val_y1_output_root_mean_squared_error: 1.9494 - val_y2_output_root_mean_squared_error: 2.9765
# Epoch 28/500
# 614/614 [==============================] - 0s 129us/sample - loss: 9.8361 - y1_output_loss: 3.6349 - y2_output_loss: 6.3879 - y1_output_root_mean_squared_error: 1.8711 - y2_output_root_mean_squared_error: 2.5169 - val_loss: 24.5663 - val_y1_output_loss: 7.0784 - val_y2_output_loss: 17.7260 - val_y1_output_root_mean_squared_error: 2.6458 - val_y2_output_root_mean_squared_error: 4.1912
# Epoch 29/500
# 614/614 [==============================] - 0s 136us/sample - loss: 11.3669 - y1_output_loss: 3.8887 - y2_output_loss: 7.4394 - y1_output_root_mean_squared_error: 1.9756 - y2_output_root_mean_squared_error: 2.7320 - val_loss: 16.8679 - val_y1_output_loss: 5.5384 - val_y2_output_loss: 11.2204 - val_y1_output_root_mean_squared_error: 2.3655 - val_y2_output_root_mean_squared_error: 3.3574
# Epoch 30/500
# 614/614 [==============================] - 0s 130us/sample - loss: 12.1769 - y1_output_loss: 3.9039 - y2_output_loss: 8.2229 - y1_output_root_mean_squared_error: 1.9813 - y2_output_root_mean_squared_error: 2.8725 - val_loss: 12.0610 - val_y1_output_loss: 4.4085 - val_y2_output_loss: 7.5843 - val_y1_output_root_mean_squared_error: 2.0937 - val_y2_output_root_mean_squared_error: 2.7708
# Epoch 31/500
# 614/614 [==============================] - 0s 133us/sample - loss: 9.7951 - y1_output_loss: 3.2741 - y2_output_loss: 6.4378 - y1_output_root_mean_squared_error: 1.8168 - y2_output_root_mean_squared_error: 2.5484 - val_loss: 7.1703 - val_y1_output_loss: 2.4033 - val_y2_output_loss: 4.5831 - val_y1_output_root_mean_squared_error: 1.5682 - val_y2_output_root_mean_squared_error: 2.1705
# Epoch 32/500
# 614/614 [==============================] - 0s 129us/sample - loss: 9.2877 - y1_output_loss: 3.1776 - y2_output_loss: 6.0228 - y1_output_root_mean_squared_error: 1.7911 - y2_output_root_mean_squared_error: 2.4657 - val_loss: 7.4259 - val_y1_output_loss: 2.8107 - val_y2_output_loss: 4.3667 - val_y1_output_root_mean_squared_error: 1.7073 - val_y2_output_root_mean_squared_error: 2.1239
# Epoch 33/500
# 614/614 [==============================] - 0s 129us/sample - loss: 8.3775 - y1_output_loss: 2.8342 - y2_output_loss: 5.5466 - y1_output_root_mean_squared_error: 1.6858 - y2_output_root_mean_squared_error: 2.3528 - val_loss: 7.8022 - val_y1_output_loss: 2.7601 - val_y2_output_loss: 4.8611 - val_y1_output_root_mean_squared_error: 1.6852 - val_y2_output_root_mean_squared_error: 2.2276
# Epoch 34/500
# 614/614 [==============================] - 0s 135us/sample - loss: 7.6896 - y1_output_loss: 2.8065 - y2_output_loss: 4.9136 - y1_output_root_mean_squared_error: 1.6695 - y2_output_root_mean_squared_error: 2.2141 - val_loss: 10.6575 - val_y1_output_loss: 2.9702 - val_y2_output_loss: 7.4066 - val_y1_output_root_mean_squared_error: 1.7397 - val_y2_output_root_mean_squared_error: 2.7624
# Epoch 35/500
# 614/614 [==============================] - 0s 134us/sample - loss: 10.3369 - y1_output_loss: 3.4086 - y2_output_loss: 6.8388 - y1_output_root_mean_squared_error: 1.8543 - y2_output_root_mean_squared_error: 2.6265 - val_loss: 6.4965 - val_y1_output_loss: 2.2331 - val_y2_output_loss: 4.0416 - val_y1_output_root_mean_squared_error: 1.5204 - val_y2_output_root_mean_squared_error: 2.0457
# Epoch 36/500
# 614/614 [==============================] - 0s 132us/sample - loss: 7.5504 - y1_output_loss: 2.6181 - y2_output_loss: 4.9283 - y1_output_root_mean_squared_error: 1.6125 - y2_output_root_mean_squared_error: 2.2249 - val_loss: 8.1347 - val_y1_output_loss: 2.6329 - val_y2_output_loss: 5.4293 - val_y1_output_root_mean_squared_error: 1.6316 - val_y2_output_root_mean_squared_error: 2.3394
# Epoch 37/500
# 614/614 [==============================] - 0s 129us/sample - loss: 8.1057 - y1_output_loss: 2.6301 - y2_output_loss: 5.4257 - y1_output_root_mean_squared_error: 1.6216 - y2_output_root_mean_squared_error: 2.3401 - val_loss: 6.1607 - val_y1_output_loss: 2.1553 - val_y2_output_loss: 3.8579 - val_y1_output_root_mean_squared_error: 1.4822 - val_y2_output_root_mean_squared_error: 1.9909
# Epoch 38/500
# 614/614 [==============================] - 0s 128us/sample - loss: 7.1900 - y1_output_loss: 2.4687 - y2_output_loss: 4.8342 - y1_output_root_mean_squared_error: 1.5642 - y2_output_root_mean_squared_error: 2.1779 - val_loss: 29.6077 - val_y1_output_loss: 6.8235 - val_y2_output_loss: 23.1962 - val_y1_output_root_mean_squared_error: 2.5839 - val_y2_output_root_mean_squared_error: 4.7887
# Epoch 39/500
# 614/614 [==============================] - 0s 132us/sample - loss: 10.4312 - y1_output_loss: 3.1579 - y2_output_loss: 7.1822 - y1_output_root_mean_squared_error: 1.7848 - y2_output_root_mean_squared_error: 2.6918 - val_loss: 5.7061 - val_y1_output_loss: 1.9744 - val_y2_output_loss: 3.5526 - val_y1_output_root_mean_squared_error: 1.4282 - val_y2_output_root_mean_squared_error: 1.9148
# Epoch 40/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.1468 - y1_output_loss: 2.2871 - y2_output_loss: 4.8025 - y1_output_root_mean_squared_error: 1.5162 - y2_output_root_mean_squared_error: 2.2018 - val_loss: 5.4822 - val_y1_output_loss: 1.7244 - val_y2_output_loss: 3.6242 - val_y1_output_root_mean_squared_error: 1.3313 - val_y2_output_root_mean_squared_error: 1.9261
# Epoch 41/500
# 614/614 [==============================] - 0s 125us/sample - loss: 11.1274 - y1_output_loss: 3.6796 - y2_output_loss: 7.4195 - y1_output_root_mean_squared_error: 1.9173 - y2_output_root_mean_squared_error: 2.7297 - val_loss: 8.1015 - val_y1_output_loss: 2.7166 - val_y2_output_loss: 5.3653 - val_y1_output_root_mean_squared_error: 1.6497 - val_y2_output_root_mean_squared_error: 2.3195
# Epoch 42/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.7033 - y1_output_loss: 2.0514 - y2_output_loss: 4.6582 - y1_output_root_mean_squared_error: 1.4342 - y2_output_root_mean_squared_error: 2.1555 - val_loss: 8.1063 - val_y1_output_loss: 2.9071 - val_y2_output_loss: 5.2086 - val_y1_output_root_mean_squared_error: 1.7016 - val_y2_output_root_mean_squared_error: 2.2828
# Epoch 43/500
# 614/614 [==============================] - 0s 132us/sample - loss: 8.0922 - y1_output_loss: 2.4061 - y2_output_loss: 5.6836 - y1_output_root_mean_squared_error: 1.5568 - y2_output_root_mean_squared_error: 2.3809 - val_loss: 12.4003 - val_y1_output_loss: 1.7658 - val_y2_output_loss: 10.7163 - val_y1_output_root_mean_squared_error: 1.3363 - val_y2_output_root_mean_squared_error: 3.2580
# Epoch 44/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.3744 - y1_output_loss: 1.8928 - y2_output_loss: 4.4649 - y1_output_root_mean_squared_error: 1.3737 - y2_output_root_mean_squared_error: 2.1183 - val_loss: 7.8532 - val_y1_output_loss: 2.1948 - val_y2_output_loss: 5.7767 - val_y1_output_root_mean_squared_error: 1.4707 - val_y2_output_root_mean_squared_error: 2.3854
# Epoch 45/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.6534 - y1_output_loss: 2.0287 - y2_output_loss: 4.5678 - y1_output_root_mean_squared_error: 1.4304 - y2_output_root_mean_squared_error: 2.1465 - val_loss: 6.1702 - val_y1_output_loss: 1.9913 - val_y2_output_loss: 4.0196 - val_y1_output_root_mean_squared_error: 1.4224 - val_y2_output_root_mean_squared_error: 2.0364
# Epoch 46/500
# 614/614 [==============================] - 0s 121us/sample - loss: 6.6158 - y1_output_loss: 1.9049 - y2_output_loss: 4.7272 - y1_output_root_mean_squared_error: 1.3846 - y2_output_root_mean_squared_error: 2.1677 - val_loss: 5.4755 - val_y1_output_loss: 1.6709 - val_y2_output_loss: 3.6306 - val_y1_output_root_mean_squared_error: 1.3136 - val_y2_output_root_mean_squared_error: 1.9365
# Epoch 47/500
# 614/614 [==============================] - 0s 131us/sample - loss: 7.6037 - y1_output_loss: 2.2924 - y2_output_loss: 5.2932 - y1_output_root_mean_squared_error: 1.5157 - y2_output_root_mean_squared_error: 2.3036 - val_loss: 9.2795 - val_y1_output_loss: 2.3249 - val_y2_output_loss: 7.0721 - val_y1_output_root_mean_squared_error: 1.5137 - val_y2_output_root_mean_squared_error: 2.6435
# Epoch 48/500
# 614/614 [==============================] - 0s 142us/sample - loss: 6.5892 - y1_output_loss: 2.0477 - y2_output_loss: 4.5848 - y1_output_root_mean_squared_error: 1.4243 - y2_output_root_mean_squared_error: 2.1355 - val_loss: 13.9347 - val_y1_output_loss: 4.1443 - val_y2_output_loss: 10.1637 - val_y1_output_root_mean_squared_error: 2.0033 - val_y2_output_root_mean_squared_error: 3.1498
# Epoch 49/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.1301 - y1_output_loss: 2.0129 - y2_output_loss: 5.0935 - y1_output_root_mean_squared_error: 1.4127 - y2_output_root_mean_squared_error: 2.2659 - val_loss: 6.7795 - val_y1_output_loss: 2.1750 - val_y2_output_loss: 4.8338 - val_y1_output_root_mean_squared_error: 1.4449 - val_y2_output_root_mean_squared_error: 2.1661
# Epoch 50/500
# 614/614 [==============================] - 0s 128us/sample - loss: 6.4517 - y1_output_loss: 1.8994 - y2_output_loss: 4.5477 - y1_output_root_mean_squared_error: 1.3777 - y2_output_root_mean_squared_error: 2.1339 - val_loss: 6.0370 - val_y1_output_loss: 2.1856 - val_y2_output_loss: 3.7298 - val_y1_output_root_mean_squared_error: 1.4832 - val_y2_output_root_mean_squared_error: 1.9589
# Epoch 51/500
# 614/614 [==============================] - 0s 128us/sample - loss: 6.7334 - y1_output_loss: 1.8954 - y2_output_loss: 4.8616 - y1_output_root_mean_squared_error: 1.3780 - y2_output_root_mean_squared_error: 2.1987 - val_loss: 6.7743 - val_y1_output_loss: 2.1803 - val_y2_output_loss: 4.5733 - val_y1_output_root_mean_squared_error: 1.4786 - val_y2_output_root_mean_squared_error: 2.1420
# Epoch 52/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.5407 - y1_output_loss: 1.6764 - y2_output_loss: 4.8298 - y1_output_root_mean_squared_error: 1.2928 - y2_output_root_mean_squared_error: 2.2067 - val_loss: 5.6111 - val_y1_output_loss: 1.8403 - val_y2_output_loss: 3.6137 - val_y1_output_root_mean_squared_error: 1.3749 - val_y2_output_root_mean_squared_error: 1.9289
# Epoch 53/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.3513 - y1_output_loss: 1.7817 - y2_output_loss: 4.5713 - y1_output_root_mean_squared_error: 1.3335 - y2_output_root_mean_squared_error: 2.1385 - val_loss: 4.7495 - val_y1_output_loss: 1.4939 - val_y2_output_loss: 3.2036 - val_y1_output_root_mean_squared_error: 1.2231 - val_y2_output_root_mean_squared_error: 1.8038
# Epoch 54/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.9736 - y1_output_loss: 1.7156 - y2_output_loss: 4.2352 - y1_output_root_mean_squared_error: 1.3104 - y2_output_root_mean_squared_error: 2.0631 - val_loss: 7.4373 - val_y1_output_loss: 2.2312 - val_y2_output_loss: 5.0149 - val_y1_output_root_mean_squared_error: 1.5114 - val_y2_output_root_mean_squared_error: 2.2700
# Epoch 55/500
# 614/614 [==============================] - 0s 137us/sample - loss: 5.6825 - y1_output_loss: 1.6658 - y2_output_loss: 4.0181 - y1_output_root_mean_squared_error: 1.2949 - y2_output_root_mean_squared_error: 2.0014 - val_loss: 10.7399 - val_y1_output_loss: 2.9009 - val_y2_output_loss: 7.6730 - val_y1_output_root_mean_squared_error: 1.7238 - val_y2_output_root_mean_squared_error: 2.7872
# Epoch 56/500
# 614/614 [==============================] - 0s 132us/sample - loss: 6.2196 - y1_output_loss: 1.6516 - y2_output_loss: 4.7218 - y1_output_root_mean_squared_error: 1.2873 - y2_output_root_mean_squared_error: 2.1360 - val_loss: 22.9478 - val_y1_output_loss: 3.8444 - val_y2_output_loss: 18.6491 - val_y1_output_root_mean_squared_error: 1.9842 - val_y2_output_root_mean_squared_error: 4.3601
# Epoch 57/500
# 614/614 [==============================] - 0s 127us/sample - loss: 10.5952 - y1_output_loss: 2.8825 - y2_output_loss: 7.6656 - y1_output_root_mean_squared_error: 1.7043 - y2_output_root_mean_squared_error: 2.7732 - val_loss: 5.4617 - val_y1_output_loss: 1.7460 - val_y2_output_loss: 3.6746 - val_y1_output_root_mean_squared_error: 1.3127 - val_y2_output_root_mean_squared_error: 1.9335
# Epoch 58/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.2587 - y1_output_loss: 1.3591 - y2_output_loss: 3.9332 - y1_output_root_mean_squared_error: 1.1561 - y2_output_root_mean_squared_error: 1.9804 - val_loss: 8.0645 - val_y1_output_loss: 2.1370 - val_y2_output_loss: 5.9619 - val_y1_output_root_mean_squared_error: 1.4653 - val_y2_output_root_mean_squared_error: 2.4326
# Epoch 59/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.0485 - y1_output_loss: 1.9516 - y2_output_loss: 5.0513 - y1_output_root_mean_squared_error: 1.4018 - y2_output_root_mean_squared_error: 2.2547 - val_loss: 4.8995 - val_y1_output_loss: 1.4063 - val_y2_output_loss: 3.3679 - val_y1_output_root_mean_squared_error: 1.1969 - val_y2_output_root_mean_squared_error: 1.8619
# Epoch 60/500
# 614/614 [==============================] - 0s 136us/sample - loss: 6.6460 - y1_output_loss: 1.8321 - y2_output_loss: 5.1248 - y1_output_root_mean_squared_error: 1.3204 - y2_output_root_mean_squared_error: 2.2142 - val_loss: 11.6850 - val_y1_output_loss: 5.5748 - val_y2_output_loss: 6.7557 - val_y1_output_root_mean_squared_error: 2.2878 - val_y2_output_root_mean_squared_error: 2.5399
# Epoch 61/500
# 614/614 [==============================] - 0s 134us/sample - loss: 7.1362 - y1_output_loss: 1.9312 - y2_output_loss: 5.1518 - y1_output_root_mean_squared_error: 1.3930 - y2_output_root_mean_squared_error: 2.2794 - val_loss: 4.3345 - val_y1_output_loss: 1.3484 - val_y2_output_loss: 2.9512 - val_y1_output_root_mean_squared_error: 1.1586 - val_y2_output_root_mean_squared_error: 1.7298
# Epoch 62/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.9112 - y1_output_loss: 1.4504 - y2_output_loss: 3.4570 - y1_output_root_mean_squared_error: 1.2041 - y2_output_root_mean_squared_error: 1.8605 - val_loss: 4.6672 - val_y1_output_loss: 1.2642 - val_y2_output_loss: 3.3167 - val_y1_output_root_mean_squared_error: 1.1308 - val_y2_output_root_mean_squared_error: 1.8407
# Epoch 63/500
# 614/614 [==============================] - 0s 127us/sample - loss: 5.1766 - y1_output_loss: 1.4287 - y2_output_loss: 3.7763 - y1_output_root_mean_squared_error: 1.1896 - y2_output_root_mean_squared_error: 1.9394 - val_loss: 6.3875 - val_y1_output_loss: 1.9739 - val_y2_output_loss: 4.2292 - val_y1_output_root_mean_squared_error: 1.4217 - val_y2_output_root_mean_squared_error: 2.0896
# Epoch 64/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.9972 - y1_output_loss: 1.3334 - y2_output_loss: 3.6520 - y1_output_root_mean_squared_error: 1.1536 - y2_output_root_mean_squared_error: 1.9148 - val_loss: 5.1689 - val_y1_output_loss: 1.8107 - val_y2_output_loss: 3.3056 - val_y1_output_root_mean_squared_error: 1.3352 - val_y2_output_root_mean_squared_error: 1.8402
# Epoch 65/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.5702 - y1_output_loss: 1.1754 - y2_output_loss: 3.3753 - y1_output_root_mean_squared_error: 1.0878 - y2_output_root_mean_squared_error: 1.8404 - val_loss: 4.7758 - val_y1_output_loss: 1.0358 - val_y2_output_loss: 3.6528 - val_y1_output_root_mean_squared_error: 1.0203 - val_y2_output_root_mean_squared_error: 1.9325
# Epoch 66/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.0170 - y1_output_loss: 0.9472 - y2_output_loss: 3.0421 - y1_output_root_mean_squared_error: 0.9753 - y2_output_root_mean_squared_error: 1.7509 - val_loss: 4.1227 - val_y1_output_loss: 1.2421 - val_y2_output_loss: 2.8776 - val_y1_output_root_mean_squared_error: 1.1157 - val_y2_output_root_mean_squared_error: 1.6964
# Epoch 67/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.9836 - y1_output_loss: 1.0097 - y2_output_loss: 2.9660 - y1_output_root_mean_squared_error: 1.0080 - y2_output_root_mean_squared_error: 1.7227 - val_loss: 4.4931 - val_y1_output_loss: 0.7647 - val_y2_output_loss: 3.6053 - val_y1_output_root_mean_squared_error: 0.8859 - val_y2_output_root_mean_squared_error: 1.9257
# Epoch 68/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.2351 - y1_output_loss: 1.0143 - y2_output_loss: 4.1796 - y1_output_root_mean_squared_error: 1.0097 - y2_output_root_mean_squared_error: 2.0532 - val_loss: 3.2520 - val_y1_output_loss: 0.7421 - val_y2_output_loss: 2.4713 - val_y1_output_root_mean_squared_error: 0.8638 - val_y2_output_root_mean_squared_error: 1.5830
# Epoch 69/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.8576 - y1_output_loss: 0.9539 - y2_output_loss: 2.8959 - y1_output_root_mean_squared_error: 0.9702 - y2_output_root_mean_squared_error: 1.7077 - val_loss: 3.8527 - val_y1_output_loss: 1.1180 - val_y2_output_loss: 2.7621 - val_y1_output_root_mean_squared_error: 1.0432 - val_y2_output_root_mean_squared_error: 1.6627
# Epoch 70/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.8997 - y1_output_loss: 0.8709 - y2_output_loss: 3.0112 - y1_output_root_mean_squared_error: 0.9376 - y2_output_root_mean_squared_error: 1.7380 - val_loss: 4.1847 - val_y1_output_loss: 0.7385 - val_y2_output_loss: 3.3297 - val_y1_output_root_mean_squared_error: 0.8675 - val_y2_output_root_mean_squared_error: 1.8526
# Epoch 71/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.2924 - y1_output_loss: 0.9956 - y2_output_loss: 3.2992 - y1_output_root_mean_squared_error: 0.9993 - y2_output_root_mean_squared_error: 1.8149 - val_loss: 14.9739 - val_y1_output_loss: 2.5912 - val_y2_output_loss: 12.2958 - val_y1_output_root_mean_squared_error: 1.6082 - val_y2_output_root_mean_squared_error: 3.5196
# Epoch 72/500
# 614/614 [==============================] - 0s 134us/sample - loss: 5.9675 - y1_output_loss: 1.6004 - y2_output_loss: 4.3422 - y1_output_root_mean_squared_error: 1.2691 - y2_output_root_mean_squared_error: 2.0873 - val_loss: 4.4858 - val_y1_output_loss: 1.1298 - val_y2_output_loss: 3.4601 - val_y1_output_root_mean_squared_error: 1.0166 - val_y2_output_root_mean_squared_error: 1.8580
# Epoch 73/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.8259 - y1_output_loss: 0.8815 - y2_output_loss: 2.9211 - y1_output_root_mean_squared_error: 0.9405 - y2_output_root_mean_squared_error: 1.7151 - val_loss: 3.2796 - val_y1_output_loss: 0.7960 - val_y2_output_loss: 2.4156 - val_y1_output_root_mean_squared_error: 0.9052 - val_y2_output_root_mean_squared_error: 1.5685
# Epoch 74/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.6625 - y1_output_loss: 0.7949 - y2_output_loss: 2.8759 - y1_output_root_mean_squared_error: 0.8940 - y2_output_root_mean_squared_error: 1.6921 - val_loss: 6.8939 - val_y1_output_loss: 1.1164 - val_y2_output_loss: 5.5739 - val_y1_output_root_mean_squared_error: 1.0717 - val_y2_output_root_mean_squared_error: 2.3970
# Epoch 75/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.9562 - y1_output_loss: 0.9532 - y2_output_loss: 3.0636 - y1_output_root_mean_squared_error: 0.9764 - y2_output_root_mean_squared_error: 1.7329 - val_loss: 6.1782 - val_y1_output_loss: 1.1983 - val_y2_output_loss: 4.8446 - val_y1_output_root_mean_squared_error: 1.1088 - val_y2_output_root_mean_squared_error: 2.2246
# Epoch 76/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.0706 - y1_output_loss: 1.1945 - y2_output_loss: 3.8605 - y1_output_root_mean_squared_error: 1.0931 - y2_output_root_mean_squared_error: 1.9687 - val_loss: 5.3823 - val_y1_output_loss: 1.9511 - val_y2_output_loss: 3.6620 - val_y1_output_root_mean_squared_error: 1.3620 - val_y2_output_root_mean_squared_error: 1.8781
# Epoch 77/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.1109 - y1_output_loss: 1.0819 - y2_output_loss: 3.0285 - y1_output_root_mean_squared_error: 1.0450 - y2_output_root_mean_squared_error: 1.7375 - val_loss: 4.1133 - val_y1_output_loss: 0.7528 - val_y2_output_loss: 3.2280 - val_y1_output_root_mean_squared_error: 0.8803 - val_y2_output_root_mean_squared_error: 1.8271
# Epoch 78/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.9410 - y1_output_loss: 1.0000 - y2_output_loss: 3.9185 - y1_output_root_mean_squared_error: 1.0019 - y2_output_root_mean_squared_error: 1.9843 - val_loss: 3.0734 - val_y1_output_loss: 0.5966 - val_y2_output_loss: 2.4450 - val_y1_output_root_mean_squared_error: 0.7704 - val_y2_output_root_mean_squared_error: 1.5748
# Epoch 79/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.0697 - y1_output_loss: 0.6810 - y2_output_loss: 2.4071 - y1_output_root_mean_squared_error: 0.8214 - y2_output_root_mean_squared_error: 1.5476 - val_loss: 9.6410 - val_y1_output_loss: 1.9584 - val_y2_output_loss: 7.8355 - val_y1_output_root_mean_squared_error: 1.3820 - val_y2_output_root_mean_squared_error: 2.7805
# Epoch 80/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.3339 - y1_output_loss: 1.0049 - y2_output_loss: 3.3303 - y1_output_root_mean_squared_error: 1.0056 - y2_output_root_mean_squared_error: 1.8228 - val_loss: 4.9143 - val_y1_output_loss: 0.9020 - val_y2_output_loss: 3.8810 - val_y1_output_root_mean_squared_error: 0.9564 - val_y2_output_root_mean_squared_error: 1.9999
# Epoch 81/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.3869 - y1_output_loss: 0.7219 - y2_output_loss: 2.6429 - y1_output_root_mean_squared_error: 0.8534 - y2_output_root_mean_squared_error: 1.6305 - val_loss: 3.5900 - val_y1_output_loss: 0.5900 - val_y2_output_loss: 2.9039 - val_y1_output_root_mean_squared_error: 0.7726 - val_y2_output_root_mean_squared_error: 1.7301
# Epoch 82/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.8917 - y1_output_loss: 0.5969 - y2_output_loss: 2.2755 - y1_output_root_mean_squared_error: 0.7735 - y2_output_root_mean_squared_error: 1.5144 - val_loss: 2.4125 - val_y1_output_loss: 0.5179 - val_y2_output_loss: 1.8801 - val_y1_output_root_mean_squared_error: 0.7104 - val_y2_output_root_mean_squared_error: 1.3812
# Epoch 83/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.8290 - y1_output_loss: 1.2263 - y2_output_loss: 3.5629 - y1_output_root_mean_squared_error: 1.1119 - y2_output_root_mean_squared_error: 1.8954 - val_loss: 4.3582 - val_y1_output_loss: 1.8269 - val_y2_output_loss: 2.4922 - val_y1_output_root_mean_squared_error: 1.3412 - val_y2_output_root_mean_squared_error: 1.5998
# Epoch 84/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.9730 - y1_output_loss: 1.1417 - y2_output_loss: 2.8213 - y1_output_root_mean_squared_error: 1.0689 - y2_output_root_mean_squared_error: 1.6824 - val_loss: 3.4185 - val_y1_output_loss: 0.9823 - val_y2_output_loss: 2.4076 - val_y1_output_root_mean_squared_error: 0.9903 - val_y2_output_root_mean_squared_error: 1.5614
# Epoch 85/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.0267 - y1_output_loss: 0.9655 - y2_output_loss: 3.0317 - y1_output_root_mean_squared_error: 0.9864 - y2_output_root_mean_squared_error: 1.7475 - val_loss: 3.2976 - val_y1_output_loss: 0.8094 - val_y2_output_loss: 2.3874 - val_y1_output_root_mean_squared_error: 0.9085 - val_y2_output_root_mean_squared_error: 1.5723
# Epoch 86/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.6876 - y1_output_loss: 1.2745 - y2_output_loss: 3.4179 - y1_output_root_mean_squared_error: 1.1240 - y2_output_root_mean_squared_error: 1.8504 - val_loss: 7.2898 - val_y1_output_loss: 2.8227 - val_y2_output_loss: 4.7336 - val_y1_output_root_mean_squared_error: 1.6203 - val_y2_output_root_mean_squared_error: 2.1597
# Epoch 87/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.6537 - y1_output_loss: 0.8746 - y2_output_loss: 2.7921 - y1_output_root_mean_squared_error: 0.9390 - y2_output_root_mean_squared_error: 1.6649 - val_loss: 5.1623 - val_y1_output_loss: 0.5307 - val_y2_output_loss: 4.5947 - val_y1_output_root_mean_squared_error: 0.7347 - val_y2_output_root_mean_squared_error: 2.1500
# Epoch 88/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.5673 - y1_output_loss: 0.7667 - y2_output_loss: 2.7904 - y1_output_root_mean_squared_error: 0.8690 - y2_output_root_mean_squared_error: 1.6769 - val_loss: 2.9075 - val_y1_output_loss: 0.7175 - val_y2_output_loss: 2.1895 - val_y1_output_root_mean_squared_error: 0.8249 - val_y2_output_root_mean_squared_error: 1.4924
# Epoch 89/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.5678 - y1_output_loss: 0.7456 - y2_output_loss: 2.8138 - y1_output_root_mean_squared_error: 0.8667 - y2_output_root_mean_squared_error: 1.6783 - val_loss: 2.5310 - val_y1_output_loss: 0.5809 - val_y2_output_loss: 1.9055 - val_y1_output_root_mean_squared_error: 0.7674 - val_y2_output_root_mean_squared_error: 1.3936
# Epoch 90/500
# 614/614 [==============================] - 0s 154us/sample - loss: 3.7452 - y1_output_loss: 0.8755 - y2_output_loss: 2.8470 - y1_output_root_mean_squared_error: 0.9377 - y2_output_root_mean_squared_error: 1.6929 - val_loss: 2.7862 - val_y1_output_loss: 0.8518 - val_y2_output_loss: 1.9159 - val_y1_output_root_mean_squared_error: 0.9119 - val_y2_output_root_mean_squared_error: 1.3981
# Epoch 91/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.7469 - y1_output_loss: 0.7006 - y2_output_loss: 2.0738 - y1_output_root_mean_squared_error: 0.8133 - y2_output_root_mean_squared_error: 1.4441 - val_loss: 3.1522 - val_y1_output_loss: 0.9590 - val_y2_output_loss: 2.2193 - val_y1_output_root_mean_squared_error: 0.9681 - val_y2_output_root_mean_squared_error: 1.4882
# Epoch 92/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.5807 - y1_output_loss: 0.6486 - y2_output_loss: 1.9459 - y1_output_root_mean_squared_error: 0.8008 - y2_output_root_mean_squared_error: 1.3927 - val_loss: 2.8432 - val_y1_output_loss: 0.7324 - val_y2_output_loss: 2.0715 - val_y1_output_root_mean_squared_error: 0.8557 - val_y2_output_root_mean_squared_error: 1.4529
# Epoch 93/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.1761 - y1_output_loss: 0.9327 - y2_output_loss: 3.2278 - y1_output_root_mean_squared_error: 0.9690 - y2_output_root_mean_squared_error: 1.7992 - val_loss: 3.2868 - val_y1_output_loss: 0.6250 - val_y2_output_loss: 2.6184 - val_y1_output_root_mean_squared_error: 0.7787 - val_y2_output_root_mean_squared_error: 1.6372
# Epoch 94/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.5543 - y1_output_loss: 0.6319 - y2_output_loss: 1.9419 - y1_output_root_mean_squared_error: 0.7955 - y2_output_root_mean_squared_error: 1.3862 - val_loss: 9.9405 - val_y1_output_loss: 0.7224 - val_y2_output_loss: 9.1043 - val_y1_output_root_mean_squared_error: 0.8480 - val_y2_output_root_mean_squared_error: 3.0367
# Epoch 95/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.5114 - y1_output_loss: 1.1045 - y2_output_loss: 3.4223 - y1_output_root_mean_squared_error: 1.0555 - y2_output_root_mean_squared_error: 1.8432 - val_loss: 8.6801 - val_y1_output_loss: 1.1399 - val_y2_output_loss: 7.4253 - val_y1_output_root_mean_squared_error: 1.0671 - val_y2_output_root_mean_squared_error: 2.7462
# Epoch 96/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.9906 - y1_output_loss: 0.7041 - y2_output_loss: 2.2609 - y1_output_root_mean_squared_error: 0.8422 - y2_output_root_mean_squared_error: 1.5104 - val_loss: 2.0879 - val_y1_output_loss: 0.4607 - val_y2_output_loss: 1.6048 - val_y1_output_root_mean_squared_error: 0.6632 - val_y2_output_root_mean_squared_error: 1.2838
# Epoch 97/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.4785 - y1_output_loss: 0.5264 - y2_output_loss: 1.9487 - y1_output_root_mean_squared_error: 0.7236 - y2_output_root_mean_squared_error: 1.3982 - val_loss: 2.5317 - val_y1_output_loss: 0.4867 - val_y2_output_loss: 2.0145 - val_y1_output_root_mean_squared_error: 0.6905 - val_y2_output_root_mean_squared_error: 1.4335
# Epoch 98/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.5538 - y1_output_loss: 0.4880 - y2_output_loss: 2.0659 - y1_output_root_mean_squared_error: 0.7009 - y2_output_root_mean_squared_error: 1.4361 - val_loss: 3.1107 - val_y1_output_loss: 0.4795 - val_y2_output_loss: 2.6221 - val_y1_output_root_mean_squared_error: 0.6817 - val_y2_output_root_mean_squared_error: 1.6266
# Epoch 99/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.9674 - y1_output_loss: 0.6315 - y2_output_loss: 2.3310 - y1_output_root_mean_squared_error: 0.7950 - y2_output_root_mean_squared_error: 1.5282 - val_loss: 3.2277 - val_y1_output_loss: 1.1488 - val_y2_output_loss: 2.0712 - val_y1_output_root_mean_squared_error: 1.0683 - val_y2_output_root_mean_squared_error: 1.4444
# Epoch 100/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.7332 - y1_output_loss: 1.0647 - y2_output_loss: 2.6508 - y1_output_root_mean_squared_error: 1.0336 - y2_output_root_mean_squared_error: 1.6324 - val_loss: 2.3309 - val_y1_output_loss: 0.5232 - val_y2_output_loss: 1.7665 - val_y1_output_root_mean_squared_error: 0.7207 - val_y2_output_root_mean_squared_error: 1.3459
# Epoch 101/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.3814 - y1_output_loss: 0.5245 - y2_output_loss: 1.8593 - y1_output_root_mean_squared_error: 0.7259 - y2_output_root_mean_squared_error: 1.3618 - val_loss: 3.1399 - val_y1_output_loss: 0.3763 - val_y2_output_loss: 2.7003 - val_y1_output_root_mean_squared_error: 0.6084 - val_y2_output_root_mean_squared_error: 1.6642
# Epoch 102/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.1688 - y1_output_loss: 0.7150 - y2_output_loss: 2.5022 - y1_output_root_mean_squared_error: 0.8496 - y2_output_root_mean_squared_error: 1.5643 - val_loss: 5.4928 - val_y1_output_loss: 1.6019 - val_y2_output_loss: 3.8218 - val_y1_output_root_mean_squared_error: 1.2619 - val_y2_output_root_mean_squared_error: 1.9750
# Epoch 103/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.5026 - y1_output_loss: 0.8656 - y2_output_loss: 2.6102 - y1_output_root_mean_squared_error: 0.9337 - y2_output_root_mean_squared_error: 1.6220 - val_loss: 2.1393 - val_y1_output_loss: 0.4425 - val_y2_output_loss: 1.6905 - val_y1_output_root_mean_squared_error: 0.6577 - val_y2_output_root_mean_squared_error: 1.3064
# Epoch 104/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.3660 - y1_output_loss: 0.4594 - y2_output_loss: 1.8902 - y1_output_root_mean_squared_error: 0.6785 - y2_output_root_mean_squared_error: 1.3805 - val_loss: 3.1793 - val_y1_output_loss: 0.5637 - val_y2_output_loss: 2.5815 - val_y1_output_root_mean_squared_error: 0.7401 - val_y2_output_root_mean_squared_error: 1.6222
# Epoch 105/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.1743 - y1_output_loss: 0.4865 - y2_output_loss: 1.6986 - y1_output_root_mean_squared_error: 0.6948 - y2_output_root_mean_squared_error: 1.3006 - val_loss: 5.4181 - val_y1_output_loss: 1.2168 - val_y2_output_loss: 4.1155 - val_y1_output_root_mean_squared_error: 1.1000 - val_y2_output_root_mean_squared_error: 2.0514
# Epoch 106/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.2742 - y1_output_loss: 0.7934 - y2_output_loss: 2.4739 - y1_output_root_mean_squared_error: 0.8902 - y2_output_root_mean_squared_error: 1.5754 - val_loss: 2.2406 - val_y1_output_loss: 0.4906 - val_y2_output_loss: 1.7500 - val_y1_output_root_mean_squared_error: 0.6962 - val_y2_output_root_mean_squared_error: 1.3251
# Epoch 107/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.3359 - y1_output_loss: 0.5215 - y2_output_loss: 1.8028 - y1_output_root_mean_squared_error: 0.7252 - y2_output_root_mean_squared_error: 1.3454 - val_loss: 2.8499 - val_y1_output_loss: 0.6076 - val_y2_output_loss: 2.3091 - val_y1_output_root_mean_squared_error: 0.7647 - val_y2_output_root_mean_squared_error: 1.5050
# Epoch 108/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.2003 - y1_output_loss: 0.5389 - y2_output_loss: 2.6480 - y1_output_root_mean_squared_error: 0.7346 - y2_output_root_mean_squared_error: 1.6312 - val_loss: 2.9338 - val_y1_output_loss: 0.4102 - val_y2_output_loss: 2.5698 - val_y1_output_root_mean_squared_error: 0.6338 - val_y2_output_root_mean_squared_error: 1.5913
# Epoch 109/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.1500 - y1_output_loss: 0.7171 - y2_output_loss: 2.4273 - y1_output_root_mean_squared_error: 0.8473 - y2_output_root_mean_squared_error: 1.5595 - val_loss: 2.2106 - val_y1_output_loss: 0.4035 - val_y2_output_loss: 1.7766 - val_y1_output_root_mean_squared_error: 0.6384 - val_y2_output_root_mean_squared_error: 1.3428
# Epoch 110/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.6310 - y1_output_loss: 0.5987 - y2_output_loss: 2.0221 - y1_output_root_mean_squared_error: 0.7734 - y2_output_root_mean_squared_error: 1.4258 - val_loss: 2.7213 - val_y1_output_loss: 0.9823 - val_y2_output_loss: 1.6803 - val_y1_output_root_mean_squared_error: 0.9965 - val_y2_output_root_mean_squared_error: 1.3147
# Epoch 111/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.1506 - y1_output_loss: 0.8287 - y2_output_loss: 2.3001 - y1_output_root_mean_squared_error: 0.9143 - y2_output_root_mean_squared_error: 1.5214 - val_loss: 2.2982 - val_y1_output_loss: 0.3788 - val_y2_output_loss: 1.8646 - val_y1_output_root_mean_squared_error: 0.6145 - val_y2_output_root_mean_squared_error: 1.3859
# Epoch 112/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.9053 - y1_output_loss: 0.7085 - y2_output_loss: 2.2109 - y1_output_root_mean_squared_error: 0.8356 - y2_output_root_mean_squared_error: 1.4856 - val_loss: 6.2176 - val_y1_output_loss: 2.4423 - val_y2_output_loss: 3.9432 - val_y1_output_root_mean_squared_error: 1.5349 - val_y2_output_root_mean_squared_error: 1.9652
# Epoch 113/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.4219 - y1_output_loss: 0.5864 - y2_output_loss: 1.8199 - y1_output_root_mean_squared_error: 0.7652 - y2_output_root_mean_squared_error: 1.3551 - val_loss: 1.9296 - val_y1_output_loss: 0.4621 - val_y2_output_loss: 1.4896 - val_y1_output_root_mean_squared_error: 0.6593 - val_y2_output_root_mean_squared_error: 1.2227
# Epoch 114/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.4316 - y1_output_loss: 0.5659 - y2_output_loss: 1.8639 - y1_output_root_mean_squared_error: 0.7546 - y2_output_root_mean_squared_error: 1.3646 - val_loss: 2.3570 - val_y1_output_loss: 0.6317 - val_y2_output_loss: 1.6845 - val_y1_output_root_mean_squared_error: 0.7978 - val_y2_output_root_mean_squared_error: 1.3117
# Epoch 115/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.2545 - y1_output_loss: 0.9504 - y2_output_loss: 2.2761 - y1_output_root_mean_squared_error: 0.9783 - y2_output_root_mean_squared_error: 1.5157 - val_loss: 2.3157 - val_y1_output_loss: 0.5487 - val_y2_output_loss: 1.7749 - val_y1_output_root_mean_squared_error: 0.7199 - val_y2_output_root_mean_squared_error: 1.3407
# Epoch 116/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.3615 - y1_output_loss: 0.5634 - y2_output_loss: 1.7909 - y1_output_root_mean_squared_error: 0.7490 - y2_output_root_mean_squared_error: 1.3418 - val_loss: 2.3346 - val_y1_output_loss: 0.6000 - val_y2_output_loss: 1.7787 - val_y1_output_root_mean_squared_error: 0.7558 - val_y2_output_root_mean_squared_error: 1.3279
# Epoch 117/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.7499 - y1_output_loss: 0.6336 - y2_output_loss: 2.1064 - y1_output_root_mean_squared_error: 0.7947 - y2_output_root_mean_squared_error: 1.4554 - val_loss: 2.1090 - val_y1_output_loss: 0.5986 - val_y2_output_loss: 1.5756 - val_y1_output_root_mean_squared_error: 0.7419 - val_y2_output_root_mean_squared_error: 1.2484
# Epoch 118/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.0568 - y1_output_loss: 0.4864 - y2_output_loss: 1.5630 - y1_output_root_mean_squared_error: 0.6957 - y2_output_root_mean_squared_error: 1.2541 - val_loss: 3.0768 - val_y1_output_loss: 0.8211 - val_y2_output_loss: 2.2961 - val_y1_output_root_mean_squared_error: 0.8948 - val_y2_output_root_mean_squared_error: 1.5087
# Epoch 119/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.2162 - y1_output_loss: 0.5056 - y2_output_loss: 1.7193 - y1_output_root_mean_squared_error: 0.7096 - y2_output_root_mean_squared_error: 1.3087 - val_loss: 2.2524 - val_y1_output_loss: 0.4335 - val_y2_output_loss: 1.8131 - val_y1_output_root_mean_squared_error: 0.6471 - val_y2_output_root_mean_squared_error: 1.3541
# Epoch 120/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.1940 - y1_output_loss: 0.5291 - y2_output_loss: 1.6527 - y1_output_root_mean_squared_error: 0.7283 - y2_output_root_mean_squared_error: 1.2898 - val_loss: 2.7367 - val_y1_output_loss: 0.3294 - val_y2_output_loss: 2.3466 - val_y1_output_root_mean_squared_error: 0.5672 - val_y2_output_root_mean_squared_error: 1.5540
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.5532 - y1_output_loss: 0.1673 - y2_output_loss: 0.3835 - y1_output_root_mean_squared_error: 0.4083 - y2_output_root_mean_squared_error: 0.6216 - val_loss: 0.7365 - val_y1_output_loss: 0.2023 - val_y2_output_loss: 0.5532 - val_y1_output_root_mean_squared_error: 0.4368 - val_y2_output_root_mean_squared_error: 0.7387
# Epoch 462/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3437 - y1_output_loss: 0.1069 - y2_output_loss: 0.2351 - y1_output_root_mean_squared_error: 0.3273 - y2_output_root_mean_squared_error: 0.4864 - val_loss: 0.7135 - val_y1_output_loss: 0.1905 - val_y2_output_loss: 0.5446 - val_y1_output_root_mean_squared_error: 0.4192 - val_y2_output_root_mean_squared_error: 0.7333
# Epoch 463/500
# 614/614 [==============================] - 0s 135us/sample - loss: 1.0057 - y1_output_loss: 0.2311 - y2_output_loss: 0.7664 - y1_output_root_mean_squared_error: 0.4826 - y2_output_root_mean_squared_error: 0.8791 - val_loss: 1.0676 - val_y1_output_loss: 0.2243 - val_y2_output_loss: 0.8342 - val_y1_output_root_mean_squared_error: 0.4666 - val_y2_output_root_mean_squared_error: 0.9219
# Epoch 464/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.6217 - y1_output_loss: 0.1870 - y2_output_loss: 0.4312 - y1_output_root_mean_squared_error: 0.4331 - y2_output_root_mean_squared_error: 0.6588 - val_loss: 0.6840 - val_y1_output_loss: 0.1942 - val_y2_output_loss: 0.5129 - val_y1_output_root_mean_squared_error: 0.4249 - val_y2_output_root_mean_squared_error: 0.7095
# Epoch 465/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.4593 - y1_output_loss: 0.1221 - y2_output_loss: 0.3352 - y1_output_root_mean_squared_error: 0.3508 - y2_output_root_mean_squared_error: 0.5799 - val_loss: 0.6622 - val_y1_output_loss: 0.1918 - val_y2_output_loss: 0.4996 - val_y1_output_root_mean_squared_error: 0.4147 - val_y2_output_root_mean_squared_error: 0.7001
# Epoch 466/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.4623 - y1_output_loss: 0.1282 - y2_output_loss: 0.3374 - y1_output_root_mean_squared_error: 0.3586 - y2_output_root_mean_squared_error: 0.5777 - val_loss: 0.6544 - val_y1_output_loss: 0.2084 - val_y2_output_loss: 0.4585 - val_y1_output_root_mean_squared_error: 0.4464 - val_y2_output_root_mean_squared_error: 0.6746
# Epoch 467/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.5220 - y1_output_loss: 0.1442 - y2_output_loss: 0.3737 - y1_output_root_mean_squared_error: 0.3808 - y2_output_root_mean_squared_error: 0.6140 - val_loss: 0.6792 - val_y1_output_loss: 0.1961 - val_y2_output_loss: 0.5068 - val_y1_output_root_mean_squared_error: 0.4262 - val_y2_output_root_mean_squared_error: 0.7053
# Epoch 468/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3443 - y1_output_loss: 0.1104 - y2_output_loss: 0.2354 - y1_output_root_mean_squared_error: 0.3301 - y2_output_root_mean_squared_error: 0.4851 - val_loss: 0.8639 - val_y1_output_loss: 0.3496 - val_y2_output_loss: 0.5348 - val_y1_output_root_mean_squared_error: 0.5791 - val_y2_output_root_mean_squared_error: 0.7270
# Epoch 469/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4740 - y1_output_loss: 0.1399 - y2_output_loss: 0.3365 - y1_output_root_mean_squared_error: 0.3735 - y2_output_root_mean_squared_error: 0.5784 - val_loss: 1.5673 - val_y1_output_loss: 0.4729 - val_y2_output_loss: 1.2123 - val_y1_output_root_mean_squared_error: 0.6599 - val_y2_output_root_mean_squared_error: 1.0639
# Epoch 470/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.5567 - y1_output_loss: 0.1777 - y2_output_loss: 0.3763 - y1_output_root_mean_squared_error: 0.4227 - y2_output_root_mean_squared_error: 0.6149 - val_loss: 0.6899 - val_y1_output_loss: 0.2453 - val_y2_output_loss: 0.4608 - val_y1_output_root_mean_squared_error: 0.4786 - val_y2_output_root_mean_squared_error: 0.6789
# Epoch 471/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.5262 - y1_output_loss: 0.1441 - y2_output_loss: 0.3804 - y1_output_root_mean_squared_error: 0.3806 - y2_output_root_mean_squared_error: 0.6175 - val_loss: 0.6716 - val_y1_output_loss: 0.2090 - val_y2_output_loss: 0.4787 - val_y1_output_root_mean_squared_error: 0.4334 - val_y2_output_root_mean_squared_error: 0.6955
# Epoch 472/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4062 - y1_output_loss: 0.1155 - y2_output_loss: 0.2885 - y1_output_root_mean_squared_error: 0.3412 - y2_output_root_mean_squared_error: 0.5383 - val_loss: 0.6193 - val_y1_output_loss: 0.1762 - val_y2_output_loss: 0.4542 - val_y1_output_root_mean_squared_error: 0.4037 - val_y2_output_root_mean_squared_error: 0.6755
# Epoch 473/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3784 - y1_output_loss: 0.1107 - y2_output_loss: 0.2742 - y1_output_root_mean_squared_error: 0.3334 - y2_output_root_mean_squared_error: 0.5170 - val_loss: 1.3116 - val_y1_output_loss: 0.1928 - val_y2_output_loss: 1.1242 - val_y1_output_root_mean_squared_error: 0.4175 - val_y2_output_root_mean_squared_error: 1.0665
# Epoch 474/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4918 - y1_output_loss: 0.1505 - y2_output_loss: 0.3401 - y1_output_root_mean_squared_error: 0.3884 - y2_output_root_mean_squared_error: 0.5839 - val_loss: 0.6464 - val_y1_output_loss: 0.1787 - val_y2_output_loss: 0.4769 - val_y1_output_root_mean_squared_error: 0.4076 - val_y2_output_root_mean_squared_error: 0.6930
# Epoch 475/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.5653 - y1_output_loss: 0.1578 - y2_output_loss: 0.4037 - y1_output_root_mean_squared_error: 0.3983 - y2_output_root_mean_squared_error: 0.6377 - val_loss: 0.7385 - val_y1_output_loss: 0.2580 - val_y2_output_loss: 0.4988 - val_y1_output_root_mean_squared_error: 0.4856 - val_y2_output_root_mean_squared_error: 0.7090
# Epoch 476/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.5005 - y1_output_loss: 0.1274 - y2_output_loss: 0.3752 - y1_output_root_mean_squared_error: 0.3516 - y2_output_root_mean_squared_error: 0.6139 - val_loss: 1.6143 - val_y1_output_loss: 0.4664 - val_y2_output_loss: 1.1505 - val_y1_output_root_mean_squared_error: 0.6667 - val_y2_output_root_mean_squared_error: 1.0816
# Epoch 477/500
# 614/614 [==============================] - 0s 134us/sample - loss: 1.3442 - y1_output_loss: 0.3135 - y2_output_loss: 1.0342 - y1_output_root_mean_squared_error: 0.5604 - y2_output_root_mean_squared_error: 1.0149 - val_loss: 1.6074 - val_y1_output_loss: 0.2919 - val_y2_output_loss: 1.2914 - val_y1_output_root_mean_squared_error: 0.5291 - val_y2_output_root_mean_squared_error: 1.1521
# Epoch 478/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.5834 - y1_output_loss: 0.1872 - y2_output_loss: 0.3919 - y1_output_root_mean_squared_error: 0.4344 - y2_output_root_mean_squared_error: 0.6282 - val_loss: 0.5944 - val_y1_output_loss: 0.1794 - val_y2_output_loss: 0.4362 - val_y1_output_root_mean_squared_error: 0.4018 - val_y2_output_root_mean_squared_error: 0.6581
# Epoch 479/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3231 - y1_output_loss: 0.1061 - y2_output_loss: 0.2198 - y1_output_root_mean_squared_error: 0.3272 - y2_output_root_mean_squared_error: 0.4648 - val_loss: 1.2517 - val_y1_output_loss: 0.1889 - val_y2_output_loss: 1.0842 - val_y1_output_root_mean_squared_error: 0.4166 - val_y2_output_root_mean_squared_error: 1.0383
# Epoch 480/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4231 - y1_output_loss: 0.1350 - y2_output_loss: 0.2877 - y1_output_root_mean_squared_error: 0.3680 - y2_output_root_mean_squared_error: 0.5364 - val_loss: 0.8756 - val_y1_output_loss: 0.1918 - val_y2_output_loss: 0.6930 - val_y1_output_root_mean_squared_error: 0.4260 - val_y2_output_root_mean_squared_error: 0.8331
# Epoch 481/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4738 - y1_output_loss: 0.1337 - y2_output_loss: 0.3366 - y1_output_root_mean_squared_error: 0.3664 - y2_output_root_mean_squared_error: 0.5827 - val_loss: 0.6837 - val_y1_output_loss: 0.2001 - val_y2_output_loss: 0.4949 - val_y1_output_root_mean_squared_error: 0.4345 - val_y2_output_root_mean_squared_error: 0.7035
# Epoch 482/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4059 - y1_output_loss: 0.1321 - y2_output_loss: 0.2724 - y1_output_root_mean_squared_error: 0.3646 - y2_output_root_mean_squared_error: 0.5225 - val_loss: 0.6351 - val_y1_output_loss: 0.1682 - val_y2_output_loss: 0.4722 - val_y1_output_root_mean_squared_error: 0.4000 - val_y2_output_root_mean_squared_error: 0.6893
# Epoch 483/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3231 - y1_output_loss: 0.1091 - y2_output_loss: 0.2139 - y1_output_root_mean_squared_error: 0.3310 - y2_output_root_mean_squared_error: 0.4621 - val_loss: 0.8188 - val_y1_output_loss: 0.2203 - val_y2_output_loss: 0.6157 - val_y1_output_root_mean_squared_error: 0.4508 - val_y2_output_root_mean_squared_error: 0.7846
# Epoch 484/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.5253 - y1_output_loss: 0.1663 - y2_output_loss: 0.3555 - y1_output_root_mean_squared_error: 0.4086 - y2_output_root_mean_squared_error: 0.5986 - val_loss: 0.6506 - val_y1_output_loss: 0.2282 - val_y2_output_loss: 0.4414 - val_y1_output_root_mean_squared_error: 0.4550 - val_y2_output_root_mean_squared_error: 0.6660
# Epoch 485/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.4601 - y1_output_loss: 0.1256 - y2_output_loss: 0.3324 - y1_output_root_mean_squared_error: 0.3548 - y2_output_root_mean_squared_error: 0.5781 - val_loss: 0.6582 - val_y1_output_loss: 0.2006 - val_y2_output_loss: 0.4816 - val_y1_output_root_mean_squared_error: 0.4290 - val_y2_output_root_mean_squared_error: 0.6885
# Epoch 486/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4822 - y1_output_loss: 0.1342 - y2_output_loss: 0.3451 - y1_output_root_mean_squared_error: 0.3674 - y2_output_root_mean_squared_error: 0.5893 - val_loss: 0.6030 - val_y1_output_loss: 0.1706 - val_y2_output_loss: 0.4408 - val_y1_output_root_mean_squared_error: 0.3984 - val_y2_output_root_mean_squared_error: 0.6665
# Epoch 487/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.4809 - y1_output_loss: 0.1396 - y2_output_loss: 0.3405 - y1_output_root_mean_squared_error: 0.3735 - y2_output_root_mean_squared_error: 0.5843 - val_loss: 1.1397 - val_y1_output_loss: 0.2198 - val_y2_output_loss: 0.9501 - val_y1_output_root_mean_squared_error: 0.4519 - val_y2_output_root_mean_squared_error: 0.9672
# Epoch 488/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4549 - y1_output_loss: 0.1368 - y2_output_loss: 0.3212 - y1_output_root_mean_squared_error: 0.3702 - y2_output_root_mean_squared_error: 0.5638 - val_loss: 1.4105 - val_y1_output_loss: 0.4127 - val_y2_output_loss: 1.0790 - val_y1_output_root_mean_squared_error: 0.6236 - val_y2_output_root_mean_squared_error: 1.0107
# Epoch 489/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.5041 - y1_output_loss: 0.1452 - y2_output_loss: 0.3552 - y1_output_root_mean_squared_error: 0.3820 - y2_output_root_mean_squared_error: 0.5985 - val_loss: 0.6731 - val_y1_output_loss: 0.1770 - val_y2_output_loss: 0.5141 - val_y1_output_root_mean_squared_error: 0.4103 - val_y2_output_root_mean_squared_error: 0.7104
# Epoch 490/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4465 - y1_output_loss: 0.1312 - y2_output_loss: 0.3217 - y1_output_root_mean_squared_error: 0.3626 - y2_output_root_mean_squared_error: 0.5612 - val_loss: 0.9070 - val_y1_output_loss: 0.2720 - val_y2_output_loss: 0.6462 - val_y1_output_root_mean_squared_error: 0.5084 - val_y2_output_root_mean_squared_error: 0.8053
# Epoch 491/500
# 614/614 [==============================] - 0s 120us/sample - loss: 0.4895 - y1_output_loss: 0.1340 - y2_output_loss: 0.3531 - y1_output_root_mean_squared_error: 0.3669 - y2_output_root_mean_squared_error: 0.5957 - val_loss: 0.6064 - val_y1_output_loss: 0.1893 - val_y2_output_loss: 0.4349 - val_y1_output_root_mean_squared_error: 0.4176 - val_y2_output_root_mean_squared_error: 0.6573
# Epoch 492/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.5062 - y1_output_loss: 0.1548 - y2_output_loss: 0.3502 - y1_output_root_mean_squared_error: 0.3916 - y2_output_root_mean_squared_error: 0.5940 - val_loss: 1.3005 - val_y1_output_loss: 0.3329 - val_y2_output_loss: 0.9620 - val_y1_output_root_mean_squared_error: 0.5631 - val_y2_output_root_mean_squared_error: 0.9917
# Epoch 493/500
# 614/614 [==============================] - 0s 161us/sample - loss: 1.0920 - y1_output_loss: 0.2375 - y2_output_loss: 0.8516 - y1_output_root_mean_squared_error: 0.4878 - y2_output_root_mean_squared_error: 0.9242 - val_loss: 0.9981 - val_y1_output_loss: 0.2802 - val_y2_output_loss: 0.7459 - val_y1_output_root_mean_squared_error: 0.5132 - val_y2_output_root_mean_squared_error: 0.8572
# Epoch 494/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3536 - y1_output_loss: 0.1176 - y2_output_loss: 0.2367 - y1_output_root_mean_squared_error: 0.3426 - y2_output_root_mean_squared_error: 0.4861 - val_loss: 0.8145 - val_y1_output_loss: 0.2315 - val_y2_output_loss: 0.5994 - val_y1_output_root_mean_squared_error: 0.4677 - val_y2_output_root_mean_squared_error: 0.7718
# Epoch 495/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3707 - y1_output_loss: 0.1189 - y2_output_loss: 0.2514 - y1_output_root_mean_squared_error: 0.3448 - y2_output_root_mean_squared_error: 0.5018 - val_loss: 1.0540 - val_y1_output_loss: 0.2638 - val_y2_output_loss: 0.8355 - val_y1_output_root_mean_squared_error: 0.4948 - val_y2_output_root_mean_squared_error: 0.8995
# Epoch 496/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3426 - y1_output_loss: 0.1122 - y2_output_loss: 0.2297 - y1_output_root_mean_squared_error: 0.3357 - y2_output_root_mean_squared_error: 0.4794 - val_loss: 0.7534 - val_y1_output_loss: 0.2081 - val_y2_output_loss: 0.5646 - val_y1_output_root_mean_squared_error: 0.4476 - val_y2_output_root_mean_squared_error: 0.7436
# Epoch 497/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4438 - y1_output_loss: 0.1348 - y2_output_loss: 0.3148 - y1_output_root_mean_squared_error: 0.3660 - y2_output_root_mean_squared_error: 0.5566 - val_loss: 1.8856 - val_y1_output_loss: 0.3057 - val_y2_output_loss: 1.5628 - val_y1_output_root_mean_squared_error: 0.5378 - val_y2_output_root_mean_squared_error: 1.2635
# Epoch 498/500
# 614/614 [==============================] - 0s 122us/sample - loss: 0.9362 - y1_output_loss: 0.2630 - y2_output_loss: 0.6746 - y1_output_root_mean_squared_error: 0.5114 - y2_output_root_mean_squared_error: 0.8214 - val_loss: 1.2763 - val_y1_output_loss: 0.3524 - val_y2_output_loss: 0.9811 - val_y1_output_root_mean_squared_error: 0.5631 - val_y2_output_root_mean_squared_error: 0.9794
# Epoch 499/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4833 - y1_output_loss: 0.1508 - y2_output_loss: 0.3299 - y1_output_root_mean_squared_error: 0.3892 - y2_output_root_mean_squared_error: 0.5760 - val_loss: 0.6086 - val_y1_output_loss: 0.1747 - val_y2_output_loss: 0.4510 - val_y1_output_root_mean_squared_error: 0.4025 - val_y2_output_root_mean_squared_error: 0.6682
# Epoch 500/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4662 - y1_output_loss: 0.1271 - y2_output_loss: 0.3373 - y1_output_root_mean_squared_error: 0.3578 - y2_output_root_mean_squared_error: 0.5815 - val_loss: 0.6470 - val_y1_output_loss: 0.2123 - val_y2_output_loss: 0.4332 - val_y1_output_root_mean_squared_error: 0.4529 - val_y2_output_root_mean_squared_error: 0.6647

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 32us/sample - loss: 0.6470 - y1_output_loss: 0.2031 - y2_output_loss: 0.4374 - y1_output_root_mean_squared_error: 0.4529 - y2_output_root_mean_squared_error: 0.6647
# Loss = 0.6469730533562698, Y1_loss = 0.20305314660072327, Y1_mse = 0.4529319107532501, Y2_loss = 0.43740779161453247, Y2_mse = 0.6646997928619385

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
